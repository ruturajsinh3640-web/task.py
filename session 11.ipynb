# %%
#Use iter() and next() to manually loop through a list of 5 trending movies from BookMyShow and print each movie name one by one.anan

movie=["kalki 2898","jawan","stree 2", "pushpa","Animal"]
movie=iter(movie)

print(next(movie))
print(next(movie))
print(next(movie))
print(next(movie))
print(next(movie))
# Out:
# kalki 2898
# jawan
# stree 2
# pushpa
# Animal

# %%
#Create a playlist of 6 songs (as a list of strings) and use enumerate() to print each song with its position like Spotify's tracklist (e.g., '1. Kesariya').

playlist=[
    "kesariya",
    "apna bana le",
    "pasoori",
    "tum hi ho ",
    "pee loon",
    "kahani suno",
]
for  index, song in enumerate(playlist,start=1):
       print(f"{index}. {song}")
       break
# Out:
# 1. kesariya
# 2. apna bana le
# 3. pasoori
# 4. tum hi ho
# 5. pee loon
# 6. kahani suno

# %%
# Given two lists — one of food items and one of prices — use zip() to print each food item with its price like a Zomato menu (e.g., 'Pizza - ₹250').

food_item=["pizza","butter masala","gulab jamun"]
price=[280,,220,90]

for item, price in zip(food_item,price):
    print(f"{item}-{price}")
# Out:
# pizza-280
# butter masala-60
# gulab jamun-220

# %%
#Write a generator function called insta_posts_generator(posts) that takes a list of Instagram post captions and yields one caption at a time. Use next() to get and print the next post caption each time until all captions are printed.<br><br><em><strong>Hint:</strong> Use the yield keyword inside your function and handle StopIteration when all posts are done.</em>

def insta_post_generator(posts):
    for caption in posts:
        yield caption

caption=[
    "golden hour magic"
    "weekend dump"
    "coffee and vibes"
    "chasing sunsets"
]

post_gen = insta_post_generator(caption)
print(caption)
# Out:
# ['golden hour magicweekend dumpcoffee and vibeschasing sunsets']

# %%
#  Build a generator function called cashback_generator(transactions) that takes a list of Paytm transaction amounts and yields 5% cashback for each transaction. Print out the cashback values for all transactions.

def cashback_generator(transactions):
    for amount in transactions:
        yield amount * 0.05

paytm_transactions = [100, 500, 1200, 250, 800]

for cashback in cashback_generator(paytm_transactions):
    print(f"Cashback earned: ₹{cashback:.2f}")
# Out:
# Cashback earned: ₹5.00
# Cashback earned: ₹25.00
# Cashback earned: ₹60.00
# Cashback earned: ₹12.50
# Cashback earned: ₹40.00
