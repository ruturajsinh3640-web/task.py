# %%
#Create a Python dictionary called playlist_prices with at least 5 key-value pairs where the key is a Spotify playlist name (as a string) and the value is the playlist's price (as an integer). Print the dictionary

platlist_prices={
    "top hits 2026:, 10"
    "chill vibes:, 8"
    "workout mix:, 12"
    "lo_fi beats:, 7"
    "road trip tunes:, 15"
}
print(platlist_prices)
# Out:
# {'top hits 2026:, 10chill vibes:, 8workout mix:, 12lo_fi beats:, 7road trip tunes:, 15'}

# %%
#Write a function update_playlist_price(playlist, new_price) that updates the price of a given playlist in the playlist_prices dictionary. Test it by updating the price of any one playlist and printing the updated dictionary.

# dictionary of playlist price
platlist_prices={
    "chil vibes:, 9.99"
    "workout mix:, 12.99"
    "party hit:, 14.99"
}

# function to playlist price

if 'playlist in playlist_price':
    'platlist_prices[play list]'=='15.99'
print(f"playlist  {'workout mix'} 15.99.")
"update_playlist_price('workout mix,15.99')"
print(platlist_prices)
# Out:
# playlist  workout mix 15.99.
# {'chil vibes:, 9.99workout mix:, 12.99party hit:, 14.99'}

# %%
#Remove a playlist from the playlist_prices dictionary using the del statement. Print the dictionary after deletion to confirm the change.

# dictionary of playlist price
platlist_prices={
    "chill:99"
    "workout:149"
    "party:199"
    "focus:129"
}
del platlist_prices["chill"]
print("update platlist price:", platlist_prices)
# Out:
# updated dictionary:
# {'chill:99workout:149party:199focus:129'}

# %%
#Given two sets: set1 contains the names of restaurants you have ordered from on Zomato, and set2 contains the names of restaurants you have ordered from on Swiggy, find and print the union and intersection of these sets.<br><br><em><strong>Hint:</strong> Use the union() and intersection() methods of Python sets.</em>

#  restaurants ordered from zomato and swiggy
set1={"domino's","KFC","McDOnald's","pizza hut"}
set2={"KFC","subway","pizza hut","burger"}
print("union:",set1.union(set2))
print("Intersection:",set1.intersection(set2))
# Out:
# union: {'pizza hut', "domino's", 'burger', 'KFC', "McDOnald's", 'subway'}
# Intersection: {'KFC', 'pizza hut'}
