# %%
#Create a Python script that takes any product name string (e.g., 'Redmi Note 12 Pro') and prints the name in all uppercase and all lowercase using the upper() and lower() methods.

product_name="Redmi note 12pro"

# %%
"print the name  in all uppercase()and lowercase()"
# Out:
# 'print the name  in all uppercase()and lowercase()'

# %%
print("product_name",(product_name))
# Out:
# product_name Redmi note 12pro

# %%
print('uppercase',product_name.upper())
print('lowercase',product_name.lower())
# Out:
# uppercase REDMI NOTE 12PRO
# lowercase redmi note 12pro

# %%
#Given the string 'Apple iPhone 14 Pro Max', use string slicing to extract and print only the brand name and the model (i.e., 'Apple' and 'iPhone 14 Pro Max') separately.<br><br><em><strong>Hint:</strong> Use split() to help find the split point, then use slicing for the substrings.</em>

phone="Apple iphone 14 pro"
a=phone.split()
print(a)
# Out:
# ['Apple', 'iphone', '14', 'pro']

# %%
phone="apple iphone 14 pro"
brand=phone[0:5]
model=phone[6:]
print('brand',brand)
print("model",model)
# Out:
# brand apple
# model iphone 14 pro

# %%
# Build a function format_product_display(name, price) that takes a product name and price (e.g., 'Boat Earbuds', 1299) and returns a formatted string like 'Boat Earbuds - ₹1299'.


#function to format product display'
'fromat_product_display(name,price)'
prouduct="boat earbuds,1200"
print(prouduct)
"return"" {name}-₹{price}"
# Out:
# boat earbuds,1200
# 'return {name}-₹{price}'

# %%
# Write a function clean_brand_name(name) that removes leading/trailing spaces and replaces any hyphens '-' with a single space in the input string. Test it with ' oneplus-Nord '.


def clean_brand_name(name):
    return name.strip().replace("-", " ")


brand = " oneplus-Nord "
print(clean_brand_name(brand))
# Out:
# oneplus Nord

# %%
# Suppose you have a list of messy product names: [' mi-Band 5 ', ' SAMSUNG-Galaxy ', ' realme-Book ']. Write code to clean each name (remove spaces, replace hyphens with spaces, and make the brand title case) and print the cleaned list.<br><br><em><strong>Constraint:</strong> Use at least three string methods from this session.</em>

# list of messy product name
prouduct=['mi- band 5','samsung-galaxy','realme-book']

# %%
prouduct='mi-band 5'
prouduct=prouduct.replace("-"," ")
print(prouduct)
# Out:
# mi band 5

# %%
prouduct=prouduct.title()
print(prouduct)
# Out:
# Mi Band 5

# %%
prouduct='samsung-galaxy'
prouduct=prouduct.replace("-"," ")
print(prouduct)
# Out:
# samsung galaxy

# %%
prouduct=prouduct.title()
print(prouduct)
# Out:
# Samsung Galaxy

# %%
prouduct='realme-book'
prouduct=prouduct.replace("-"," ")
print(prouduct)
# Out:
# realme book

# %%
prouduct=prouduct.title()
print(prouduct)
# Out:
# Realme Book
