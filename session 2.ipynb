# %%
# Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.

# create three variable
user_name='ruutu'
fav_app='instagram'
daily_usage_hours=3

# %%
print(user_name, fav_app,daily_usage_hours)
# Out:
# ruutu instagram 3

# %%
# Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function.

#declares variable
product_name='iphone'
price=50000
is_available=True

# %%
print(product_name,price,is_available)
# Out:
# iphone 50000 True

# %%
# print data types

# %%
print("product_name",type(product_name))
print("price",type(price))
print("is_available",type(is_available))
# Out:
# product_name <class 'str'>
# price <class 'int'>
# is_available <class 'bool'>

# %%
#single_line and muilti_line commentDemonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. Use # for single-line and triple quotes for multi-line comments.

'tracking the posts,reels'
'identifying your intereste'

# %%
# instagram recommendation system might work by
print('tracking the posts,reels')
print('identifying your intereste')
# Out:
# tracking the posts,reels
# identifying your intereste

# %%
# Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em

def greet():
    print("Hello")
    print("Welcome to Python")

greet()
# Out:
# Hello
# Welcome to Python

# %%
# Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. Follow Python naming conventions and print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'


#create varible zomato order
order_total=450
delivery_region="Ahmedabad"
discount_percent=20

# %%
# Print the order details
print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from Ahmedabad totals ₹450 with 20% discount.
